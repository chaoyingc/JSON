# %%
import json
import requests
import pandas as pd

# %%
with open ('../Data/wrong.json') as json_data:
    data_dict = json.load(json_data)
data_dict
# Out:
# {'title': 'Taxi driver',
#  'year': 1976,
#  'genre': 'drama',
#  'summary': "Vétéran de la Guerre du Vietnam, Travis Bickle est chauffeur de taxi dans la ville de New York.\n'La violence quotidienne l'affecte peu à peu.' ",
#  'country': 'USA',
#  'director': {'last_name': 'Scorcese',
#   'first_name': 'Martin',
#   'birth_date': 1962},
#  'actors': [{'first_name': 'Jodie',
#    'last_name': 'Foster',
#    'birth_date': None,
#    'role': 1962},
#   {'first_name': 'Robert',
#    'last_name': 'De Niro',
#    'birth_date': 1943,
#    'role': 'Travis Bickle'}]}

# %%
data = json.loads(open('../Data/wrong.json').read())
data
# Out:
# {'title': 'Taxi driver',
#  'year': 1976,
#  'genre': 'drama',
#  'summary': "Vétéran de la Guerre du Vietnam, Travis Bickle est chauffeur de taxi dans la ville de New York. \n'La violence quotidienne l'affecte peu à peu.' ",
#  'country': 'USA',
#  'director': {'last_name': 'Scorcese',
#   'first_name': 'Martin',
#   'birth_date': 1962},
#  'actors': [{'first_name': 'Jodie',
#    'last_name': 'Foster',
#    'birth_date': None,
#    'role': 1962},
#   {'first_name': 'Robert',
#    'last_name': 'De Niro',
#    'birth_date': 1943,
#    'role': 'Travis Bickle'}]}

# %%
with open("../Data/wrong.json",'r', newline='\n') as f:
    data_d = json.load(f)
data_d
# Out:
# {'title': 'Taxi driver',
#  'year': 1976,
#  'genre': 'drama',
#  'summary': "Vétéran de la Guerre du Vietnam, Travis Bickle est chauffeur de taxi dans la ville de New York. \n'La violence quotidienne l'affecte peu à peu.' ",
#  'country': 'USA',
#  'director': {'last_name': 'Scorcese',
#   'first_name': 'Martin',
#   'birth_date': 1962},
#  'actors': [{'first_name': 'Jodie',
#    'last_name': 'Foster',
#    'birth_date': None,
#    'role': 1962},
#   {'first_name': 'Robert',
#    'last_name': 'De Niro',
#    'birth_date': 1943,
#    'role': 'Travis Bickle'}]}

# %%
json.dumps(data,indent=1)
# Out:
# '{\n "title": "Taxi driver",\n "year": 1976,\n "genre": "drama",\n "summary": "V\\u00e9t\\u00e9ran de la Guerre du Vietnam, Travis Bickle est chauffeur de taxi dans la ville de New York.\\n\'La violence quotidienne l\'affecte peu \\u00e0 peu.\' ",\n "country": "USA",\n "director": {\n  "last_name": "Scorcese",\n  "first_name": "Martin",\n  "birth_date": 1962\n },\n "actors": [\n  {\n   "first_name": "Jodie",\n   "last_name": "Foster",\n   "birth_date": null,\n   "role": 1962\n  },\n  {\n   "first_name": "Robert",\n   "last_name": "De Niro",\n   "birth_date": 1943,\n   "role": "Travis Bickle"\n  }\n ]\n}'

# %%
url = requests.get('https://swapi.co/api/people/')
data = url.json()
data
# Out:
# {'count': 87,
#  'next': 'https://swapi.co/api/people/?page=2',
#  'previous': None,
#  'results': [{'name': 'Luke Skywalker',
#    'height': '172',
#    'mass': '77',
#    'hair_color': 'blond',
#    'skin_color': 'fair',
#    'eye_color': 'blue',
#    'birth_year': '19BBY',
#    'gender': 'male',
#    'homeworld': 'https://swapi.co/api/planets/1/',
#    'films': ['https://swapi.co/api/films/2/',
#     'https://swapi.co/api/films/6/',
#     'https://swapi.co/api/films/3/',
#     'https://swapi.co/api/films/1/',
#     'https://swapi.co/api/films/7/'],
#    'species': ['https://swapi.co/api/species/1/'],
#    'vehicles': ['https://swapi.co/api/vehicles/14/',
#     'https://swapi.co/api/vehicles/30/'],
#    'starships': ['https://swapi.co/api/starships/12/',
#     'https://swapi.co/api/starships/22/'],
#    'created': '2014-12-09T13:50:51.644000Z',
#    'edited': '2014-12-20T21:17:56.891000Z',
#    'url': 'https://swapi.co/api/people/1/'},
#   {'name': 'C-3PO',
#    'height': '167',
# ...

# %%
data['results']
# Out:
# [{'name': 'Luke Skywalker',
#   'height': '172',
#   'mass': '77',
#   'hair_color': 'blond',
#   'skin_color': 'fair',
#   'eye_color': 'blue',
#   'birth_year': '19BBY',
#   'gender': 'male',
#   'homeworld': 'https://swapi.co/api/planets/1/',
#   'films': ['https://swapi.co/api/films/2/',
#    'https://swapi.co/api/films/6/',
#    'https://swapi.co/api/films/3/',
#    'https://swapi.co/api/films/1/',
#    'https://swapi.co/api/films/7/'],
#   'species': ['https://swapi.co/api/species/1/'],
#   'vehicles': ['https://swapi.co/api/vehicles/14/',
#    'https://swapi.co/api/vehicles/30/'],
#   'starships': ['https://swapi.co/api/starships/12/',
#    'https://swapi.co/api/starships/22/'],
#   'created': '2014-12-09T13:50:51.644000Z',
#   'edited': '2014-12-20T21:17:56.891000Z',
#   'url': 'https://swapi.co/api/people/1/'},
#  {'name': 'C-3PO',
#   'height': '167',
#   'mass': '75',
#   'hair_color': 'n/a',
#   'skin_color': 'gold',
#   'eye_color': 'yellow',
#   'birth_year': '112BBY',
# ...

# %%
len(data['results'])
# Out:
# 10

# %%
data['results'][0]
# Out:
# {'name': 'Luke Skywalker',
#  'height': '172',
#  'mass': '77',
#  'hair_color': 'blond',
#  'skin_color': 'fair',
#  'eye_color': 'blue',
#  'birth_year': '19BBY',
#  'gender': 'male',
#  'homeworld': 'https://swapi.co/api/planets/1/',
#  'films': ['https://swapi.co/api/films/2/',
#   'https://swapi.co/api/films/6/',
#   'https://swapi.co/api/films/3/',
#   'https://swapi.co/api/films/1/',
#   'https://swapi.co/api/films/7/'],
#  'species': ['https://swapi.co/api/species/1/'],
#  'vehicles': ['https://swapi.co/api/vehicles/14/',
#   'https://swapi.co/api/vehicles/30/'],
#  'starships': ['https://swapi.co/api/starships/12/',
#   'https://swapi.co/api/starships/22/'],
#  'created': '2014-12-09T13:50:51.644000Z',
#  'edited': '2014-12-20T21:17:56.891000Z',
#  'url': 'https://swapi.co/api/people/1/'}

# %%
df=pd.DataFrame(data['results'])
df
# Out:
#   birth_year                      created                       edited  \
# 0      19BBY  2014-12-09T13:50:51.644000Z  2014-12-20T21:17:56.891000Z
# 1     112BBY  2014-12-10T15:10:51.357000Z  2014-12-20T21:17:50.309000Z
# 2      33BBY  2014-12-10T15:11:50.376000Z  2014-12-20T21:17:50.311000Z
# 3    41.9BBY  2014-12-10T15:18:20.704000Z  2014-12-20T21:17:50.313000Z
# 4      19BBY  2014-12-10T15:20:09.791000Z  2014-12-20T21:17:50.315000Z
# 5      52BBY  2014-12-10T15:52:14.024000Z  2014-12-20T21:17:50.317000Z
# 6      47BBY  2014-12-10T15:53:41.121000Z  2014-12-20T21:17:50.319000Z
# 7    unknown  2014-12-10T15:57:50.959000Z  2014-12-20T21:17:50.321000Z
# 8      24BBY  2014-12-10T15:59:50.509000Z  2014-12-20T21:17:50.323000Z
# 9      57BBY  2014-12-10T16:16:29.192000Z  2014-12-20T21:17:50.325000Z
#
#    eye_color                                              films  gender  \
# 0       blue  [https://swapi.co/api/films/2/, https://swapi....    male
# ...

# %%
for i in range(len(df.films)):
    df.films[i]=df.films[i][0]
    df.species[i]=df.species[i][0]
df
# Out:
#   birth_year                      created                       edited  \
# 0      19BBY  2014-12-09T13:50:51.644000Z  2014-12-20T21:17:56.891000Z
# 1     112BBY  2014-12-10T15:10:51.357000Z  2014-12-20T21:17:50.309000Z
# 2      33BBY  2014-12-10T15:11:50.376000Z  2014-12-20T21:17:50.311000Z
# 3    41.9BBY  2014-12-10T15:18:20.704000Z  2014-12-20T21:17:50.313000Z
# 4      19BBY  2014-12-10T15:20:09.791000Z  2014-12-20T21:17:50.315000Z
# 5      52BBY  2014-12-10T15:52:14.024000Z  2014-12-20T21:17:50.317000Z
# 6      47BBY  2014-12-10T15:53:41.121000Z  2014-12-20T21:17:50.319000Z
# 7    unknown  2014-12-10T15:57:50.959000Z  2014-12-20T21:17:50.321000Z
# 8      24BBY  2014-12-10T15:59:50.509000Z  2014-12-20T21:17:50.323000Z
# 9      57BBY  2014-12-10T16:16:29.192000Z  2014-12-20T21:17:50.325000Z
#
#    eye_color                          films  gender     hair_color height  \
# 0       blue  https://swapi.co/api/films/2/    male          blond    172
# ...

# %%
def cro(column):
    for i in range(len(column)):
        if len(column[i])==0:
            column[i]=float('nan')
        else:
            column[i]=column[i][0]
cro(df['starships'])

# %%
cro(df['vehicles'])

# %%
df
# Out:
#   birth_year                      created                       edited  \
# 0      19BBY  2014-12-09T13:50:51.644000Z  2014-12-20T21:17:56.891000Z
# 1     112BBY  2014-12-10T15:10:51.357000Z  2014-12-20T21:17:50.309000Z
# 2      33BBY  2014-12-10T15:11:50.376000Z  2014-12-20T21:17:50.311000Z
# 3    41.9BBY  2014-12-10T15:18:20.704000Z  2014-12-20T21:17:50.313000Z
# 4      19BBY  2014-12-10T15:20:09.791000Z  2014-12-20T21:17:50.315000Z
# 5      52BBY  2014-12-10T15:52:14.024000Z  2014-12-20T21:17:50.317000Z
# 6      47BBY  2014-12-10T15:53:41.121000Z  2014-12-20T21:17:50.319000Z
# 7    unknown  2014-12-10T15:57:50.959000Z  2014-12-20T21:17:50.321000Z
# 8      24BBY  2014-12-10T15:59:50.509000Z  2014-12-20T21:17:50.323000Z
# 9      57BBY  2014-12-10T16:16:29.192000Z  2014-12-20T21:17:50.325000Z
#
#    eye_color                          films  gender     hair_color height  \
# 0       blue  https://swapi.co/api/films/2/    male          blond    172
# ...

# %%
df=df[['name','height','mass','hair_color','skin_color','eye_color','birth_year','gender','homeworld','films','species','starships','url','vehicles','created','edited']]
df
# Out:
#                  name height mass     hair_color   skin_color  eye_color  \
# 0      Luke Skywalker    172   77          blond         fair       blue
# 1               C-3PO    167   75            n/a         gold     yellow
# 2               R2-D2     96   32            n/a  white, blue        red
# 3         Darth Vader    202  136           none        white     yellow
# 4         Leia Organa    150   49          brown        light      brown
# 5           Owen Lars    178  120    brown, grey        light       blue
# 6  Beru Whitesun lars    165   75          brown        light       blue
# 7               R5-D4     97   32            n/a   white, red        red
# 8   Biggs Darklighter    183   84          black        light      brown
# 9      Obi-Wan Kenobi    182   77  auburn, white         fair  blue-gray
#
#   birth_year  gender                         homeworld  \
# 0      19BBY    male   https://swapi.co/api/planets/1/
# ...

# %%
df.to_csv('json.csv')
